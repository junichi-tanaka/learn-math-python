# %% [markdown]
# <a href="https://colab.research.google.com/github/junichi-tanaka/learn-math-python/blob/master/notebooks/chapter3/3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# データ
x = [1, 2, 3, 4, 5, 6, 7]
y = [64.3, 63.8, 63.6, 64.0, 63.5, 63.2, 63.1]

# グラフを描画
plt.plot(x, y)
plt.grid(color='0.8')
plt.show()
